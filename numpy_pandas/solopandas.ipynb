# %%
import numpy as np
import pandas as pd

# %%
df_movies = pd.read_csv('/content/n_movies.csv')

# %%
df_movies.head(5)
# Out:
#                     title         year certificate duration  \
# 0               Cobra Kai     (2018– )       TV-14   30 min
# 1               The Crown     (2016– )       TV-MA   58 min
# 2        Better Call Saul  (2015–2022)       TV-MA   46 min
# 3           Devil in Ohio       (2022)       TV-MA  356 min
# 4  Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
#
#                           genre  rating  \
# 0         Action, Comedy, Drama     8.5
# 1     Biography, Drama, History     8.7
# 2                  Crime, Drama     8.9
# 3        Drama, Horror, Mystery     5.9
# 4  Animation, Action, Adventure     8.6
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
# 3  When a psychiatrist shelters a mysterious cult...
# 4  A Street Kid trying to survive in a technology...
#
# ...

# %%
df_movies.loc[2:7,['duration','rating']]
# Out:
#   duration  rating
# 2   46 min     8.9
# 3  356 min     5.9
# 4   24 min     8.6
# 5   45 min     7.8
# 6   23 min     9.2
# 7   49 min     9.5

# %%
df_movies.iloc[:3,2:]
# Out:
#   certificate duration                      genre  rating  \
# 0       TV-14   30 min      Action, Comedy, Drama     8.5
# 1       TV-MA   58 min  Biography, Drama, History     8.7
# 2       TV-MA   46 min               Crime, Drama     8.9
#
#                                          description  \
# 0  Decades after their 1984 All Valley Karate Tou...
# 1  Follows the political rivalries and romance of...
# 2  The trials and tribulations of criminal lawyer...
#
#                                                stars    votes
# 0  ['Ralph Macchio, ', 'William Zabka, ', 'Courtn...  177,031
# 1  ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...  199,885
# 2  ['Bob Odenkirk, ', 'Rhea Seehorn, ', 'Jonathan...  501,384

# %%
df_movies.drop_duplicates('duration')
# Out:
#                                                   title         year  \
# 0                                             Cobra Kai     (2018– )
# 1                                             The Crown     (2016– )
# 2                                      Better Call Saul  (2015–2022)
# 3                                         Devil in Ohio       (2022)
# 4                                Cyberpunk: Edgerunners     (2022– )
# ...                                                 ...          ...
# 5443                Lalbaug Parel: Zali Mumbai Sonyachi       (2010)
# 5596                  My Love: Six Stories of True Love       (2021)
# 5946  Nisman. The Prosecutor, the President and the Spy  (2019–2020)
# 5985        Reasonable Doubt: A Tale of Two Kidnappings       (2021)
# 7470                            Nietzsche and the Nazis       (2006)
#
#      certificate duration                         genre  rating  \
# 0          TV-14   30 min         Action, Comedy, Drama     8.5
# ...

# %%
df_movies['rango'] = np.arange(0,df_movies.shape[0])
df_movies
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# ...

# %%
del df_movies['rango']

# %%
df_movies
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# ...
